# %%
for i in range(0, 256):
    print("LDA #{}".format(0))
    print("STA ${}".format(str(hex(i))[2:]))

for i in range(0, 256):
    print("LDA ${}".format(str(hex(i))[2:]))
    print("ADC #{}".format(1))
    print("STA ${}".format(str(hex(i))[2:]))

print("JMP $20FF")
# Out:
# LDA #0
# STA $0
# LDA #0
# STA $1
# LDA #0
# STA $2
# LDA #0
# STA $3
# LDA #0
# STA $4
# LDA #0
# STA $5
# LDA #0
# STA $6
# LDA #0
# STA $7
# LDA #0
# STA $8
# LDA #0
# STA $9
# LDA #0
# STA $a
# LDA #0
# STA $b
# LDA #0
# STA $c
# LDA #0
# STA $d
# LDA #0
# STA $e
# LDA #0
# STA $f
# LDA #0
# STA $10
# LDA #0
# STA $11
# LDA #0
# STA $12
# LDA #0
# STA $13
# LDA #0
# STA $14
# LDA #0
# STA $15
# LDA #0
# STA $16
# LDA #0
# STA $17
# LDA #0
# STA $18
# LDA #0
# STA $19
# LDA #0
# STA $1a
# LDA #0
# STA $1b
# LDA #0
# STA $1c
# LDA #0
# STA $1d
# LDA #0
# STA $1e
# LDA #0
# STA $1f
# LDA #0
# STA $20
# LDA #0
# STA $21
# LDA #0
# STA $22
# LDA #0
# STA $23
# LDA #0
# STA $24
# LDA #0
# STA $25
# LDA #0
# STA $26
# LDA #0
# STA $27
# LDA #0
# STA $28
# LDA #0
# STA $29
# LDA #0
# STA $2a
# LDA #0
# STA $2b
# LDA #0
# STA $2c
# LDA #0
# STA $2d
# LDA #0
# STA $2e
# LDA #0
# STA $2f
# LDA #0
# STA $30
# LDA #0
# STA $31
# LDA #0
# STA $32
# LDA #0
# STA $33
# LDA #0
# STA $34
# LDA #0
# ...
