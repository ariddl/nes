# %%
for i in range(0, 256):
    print("LDA #{}".format(0))
    print("STA ${}".format(str(hex(i))[2:]))

for i in range(0, 256):
    print("LDA ${}".format(str(hex(i))[2:]))
    print("ADC #{}".format(1))
    print("STA ${}".format(str(hex(i))[2:]))


print("JMP $20FF")
# Out:
# LDA #0
# STA $0
# LDA #0
# STA $1
# LDA #0
# STA $2
# LDA #0
# STA $3
# LDA #0
# STA $4
# LDA #0
# STA $5
# LDA #0
# STA $6
# LDA #0
# STA $7
# LDA #0
# STA $8
# LDA #0
# STA $9
# LDA #0
# STA $a
# LDA #0
# STA $b
# LDA #0
# STA $c
# LDA #0
# STA $d
# LDA #0
# STA $e
# LDA #0
# STA $f
# LDA #0
# STA $10
# LDA #0
# STA $11
# LDA #0
# STA $12
# LDA #0
# STA $13
# LDA #0
# STA $14
# LDA #0
# STA $15
# LDA #0
# STA $16
# LDA #0
# STA $17
# LDA #0
# STA $18
# LDA #0
# STA $19
# LDA #0
# STA $1a
# LDA #0
# STA $1b
# LDA #0
# STA $1c
# LDA #0
# STA $1d
# LDA #0
# STA $1e
# LDA #0
# STA $1f
# LDA #0
# STA $20
# LDA #0
# STA $21
# LDA #0
# STA $22
# LDA #0
# STA $23
# LDA #0
# STA $24
# LDA #0
# STA $25
# LDA #0
# STA $26
# LDA #0
# STA $27
# LDA #0
# STA $28
# LDA #0
# STA $29
# LDA #0
# STA $2a
# LDA #0
# STA $2b
# LDA #0
# STA $2c
# LDA #0
# STA $2d
# LDA #0
# STA $2e
# LDA #0
# STA $2f
# LDA #0
# STA $30
# LDA #0
# STA $31
# LDA #0
# STA $32
# LDA #0
# STA $33
# LDA #0
# STA $34
# LDA #0
# STA $35
# LDA #0
# STA $36
# LDA #0
# STA $37
# LDA #0
# STA $38
# LDA #0
# STA $39
# LDA #0
# STA $3a
# LDA #0
# STA $3b
# LDA #0
# STA $3c
# LDA #0
# STA $3d
# LDA #0
# STA $3e
# LDA #0
# STA $3f
# LDA #0
# STA $40
# LDA #0
# STA $41
# LDA #0
# STA $42
# LDA #0
# STA $43
# LDA #0
# STA $44
# LDA #0
# STA $45
# LDA #0
# STA $46
# LDA #0
# STA $47
# LDA #0
# STA $48
# LDA #0
# STA $49
# LDA #0
# STA $4a
# LDA #0
# STA $4b
# LDA #0
# STA $4c
# LDA #0
# STA $4d
# LDA #0
# STA $4e
# LDA #0
# STA $4f
# LDA #0
# STA $50
# LDA #0
# STA $51
# LDA #0
# STA $52
# LDA #0
# STA $53
# LDA #0
# STA $54
# LDA #0
# STA $55
# LDA #0
# STA $56
# LDA #0
# STA $57
# LDA #0
# STA $58
# LDA #0
# STA $59
# LDA #0
# STA $5a
# LDA #0
# STA $5b
# LDA #0
# STA $5c
# LDA #0
# STA $5d
# LDA #0
# STA $5e
# LDA #0
# STA $5f
# LDA #0
# STA $60
# LDA #0
# STA $61
# LDA #0
# STA $62
# LDA #0
# STA $63
# LDA #0
# STA $64
# LDA #0
# STA $65
# LDA #0
# STA $66
# LDA #0
# STA $67
# LDA #0
# STA $68
# LDA #0
# STA $69
# LDA #0
# STA $6a
# LDA #0
# STA $6b
# LDA #0
# STA $6c
# LDA #0
# STA $6d
# LDA #0
# STA $6e
# LDA #0
# STA $6f
# LDA #0
# STA $70
# LDA #0
# STA $71
# LDA #0
# STA $72
# LDA #0
# STA $73
# LDA #0
# STA $74
# LDA #0
# STA $75
# LDA #0
# STA $76
# LDA #0
# STA $77
# LDA #0
# STA $78
# LDA #0
# STA $79
# LDA #0
# STA $7a
# LDA #0
# STA $7b
# LDA #0
# STA $7c
# LDA #0
# STA $7d
# LDA #0
# STA $7e
# LDA #0
# STA $7f
# LDA #0
# STA $80
# LDA #0
# STA $81
# LDA #0
# STA $82
# LDA #0
# STA $83
# LDA #0
# STA $84
# LDA #0
# STA $85
# LDA #0
# STA $86
# LDA #0
# STA $87
# LDA #0
# STA $88
# LDA #0
# STA $89
# LDA #0
# STA $8a
# LDA #0
# STA $8b
# LDA #0
# STA $8c
# LDA #0
# STA $8d
# LDA #0
# STA $8e
# LDA #0
# STA $8f
# LDA #0
# STA $90
# LDA #0
# STA $91
# LDA #0
# STA $92
# LDA #0
# STA $93
# LDA #0
# STA $94
# LDA #0
# STA $95
# LDA #0
# STA $96
# LDA #0
# STA $97
# LDA #0
# STA $98
# LDA #0
# STA $99
# LDA #0
# STA $9a
# LDA #0
# STA $9b
# LDA #0
# STA $9c
# LDA #0
# STA $9d
# LDA #0
# STA $9e
# LDA #0
# STA $9f
# LDA #0
# STA $a0
# LDA #0
# STA $a1
# LDA #0
# STA $a2
# LDA #0
# STA $a3
# LDA #0
# STA $a4
# LDA #0
# STA $a5
# LDA #0
# STA $a6
# LDA #0
# STA $a7
# LDA #0
# STA $a8
# LDA #0
# STA $a9
# LDA #0
# STA $aa
# LDA #0
# STA $ab
# LDA #0
# STA $ac
# LDA #0
# STA $ad
# LDA #0
# STA $ae
# LDA #0
# STA $af
# LDA #0
# STA $b0
# LDA #0
# STA $b1
# LDA #0
# STA $b2
# LDA #0
# STA $b3
# LDA #0
# STA $b4
# LDA #0
# STA $b5
# LDA #0
# STA $b6
# LDA #0
# STA $b7
# LDA #0
# STA $b8
# LDA #0
# STA $b9
# LDA #0
# STA $ba
# LDA #0
# STA $bb
# LDA #0
# STA $bc
# LDA #0
# STA $bd
# LDA #0
# STA $be
# LDA #0
# STA $bf
# LDA #0
# STA $c0
# LDA #0
# STA $c1
# LDA #0
# STA $c2
# LDA #0
# STA $c3
# LDA #0
# STA $c4
# LDA #0
# STA $c5
# LDA #0
# STA $c6
# LDA #0
# STA $c7
# LDA #0
# STA $c8
# LDA #0
# STA $c9
# LDA #0
# STA $ca
# LDA #0
# STA $cb
# LDA #0
# STA $cc
# LDA #0
# STA $cd
# LDA #0
# STA $ce
# LDA #0
# STA $cf
# LDA #0
# STA $d0
# LDA #0
# STA $d1
# LDA #0
# STA $d2
# LDA #0
# STA $d3
# LDA #0
# STA $d4
# LDA #0
# STA $d5
# LDA #0
# STA $d6
# LDA #0
# STA $d7
# LDA #0
# STA $d8
# LDA #0
# STA $d9
# LDA #0
# STA $da
# LDA #0
# STA $db
# LDA #0
# STA $dc
# LDA #0
# STA $dd
# LDA #0
# STA $de
# LDA #0
# STA $df
# LDA #0
# STA $e0
# LDA #0
# STA $e1
# LDA #0
# STA $e2
# LDA #0
# STA $e3
# LDA #0
# STA $e4
# LDA #0
# STA $e5
# LDA #0
# STA $e6
# LDA #0
# STA $e7
# LDA #0
# STA $e8
# LDA #0
# STA $e9
# LDA #0
# STA $ea
# LDA #0
# STA $eb
# LDA #0
# STA $ec
# LDA #0
# STA $ed
# LDA #0
# STA $ee
# LDA #0
# STA $ef
# LDA #0
# STA $f0
# LDA #0
# STA $f1
# LDA #0
# STA $f2
# LDA #0
# STA $f3
# LDA #0
# STA $f4
# LDA #0
# STA $f5
# LDA #0
# STA $f6
# LDA #0
# STA $f7
# LDA #0
# STA $f8
# LDA #0
# STA $f9
# LDA #0
# STA $fa
# LDA #0
# STA $fb
# LDA #0
# STA $fc
# LDA #0
# STA $fd
# LDA #0
# STA $fe
# LDA #0
# STA $ff
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# ADC #1
# JMP $20FF
